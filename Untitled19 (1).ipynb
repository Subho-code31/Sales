# %%
import pandas as pd
import numpy as np

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9fec050f3388> in <cell line: 0>()
# ----> 1 df= pd.read_csv("datset - Sheet1 (1).csv")
#
# NameError: name 'pd' is not defined

# %%
df = pd.read_csv("datset - Sheet1 (1).csv")

# %%
df
# Out:
#     OrderID        Date Region    CustomerName       Product  Quantity  \
# 0      1001  2023-01-15  North   Alice Johnson        Laptop       2.0
# 1      1002  2023-01-16  South     Rahul Mehta  Mobile Phone       5.0
# 2      1003  2023-01-17   East     Fatima Noor    Headphones      10.0
# 3      1004  2023-01-18   West             NaN        Laptop       1.0
# 4      1005  2023-01-19  North      Zoe Carter  Mobile Phone       3.0
# 5      1006  2023-01-20  South    Ankit Tiwari      Keyboard       4.0
# 6      1007  2023-01-21   East       Sarah Lee       Monitor       2.0
# 7      1008  2023-01-22   West    Daniel Smith        Laptop       NaN
# 8      1009  2023-01-23  North      Priya Nair  Mobile Phone       4.0
# 9      1010  2023-01-24  South     Ramesh Iyer    Headphones       6.0
# 10     1011  2023-01-25   East  Maria Gonzalez        Laptop       1.0
# 11     1012  2023-01-26   West             NaN       Monitor       2.0
# ...

# %%
Total_sales = df.groupby(['Region'],as_index=False)['TotalSales'].sum().sort_values(by='TotalSales',ascending=False)

# %%
Total_sales
# Out:
#   Region  TotalSales
# 2  South      3830.0
# 1  North      3765.0
# 0   East      2520.0
# 3   West      2425.0

# %%
avg_sales = df.groupby(["Product"],as_index=False)['TotalSales'].mean().sort_values(by='TotalSales',ascending=False)

# %%
total_sales_by_product=df.groupby(['Product'])['TotalSales'].sum()

# %%
highest_selling=total_sales_by_product.idxmax()

# %%
highest_selling
# Out:
# 'Laptop'

# %%
lowest_selling=total_sales_by_product.idxmin()

# %%
totalSales = df['TotalSales'].dropna()

# %%
totalSales_array= totalSales.to_numpy()

# %%
totalSales_array
# Out:
# array([1400., 1500.,  500.,  720.,  400.,  400., 1180.,  330.,  710.,
#         420.,  285., 1400.,  290.,  585.,  900.,  200.,  620.,  700.])

# %%
mean = np.mean(totalSales_array)

# %%
median=np.median(totalSales_array)

# %%
standard_deviation=np.std(totalSales_array)
